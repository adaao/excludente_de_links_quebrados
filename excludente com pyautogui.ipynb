# %%
import pyautogui as pag
import time
import pyperclip

# %%
checkbox_position = (337, 612)
ocultar_checkb_position = (745, 661)

time.sleep(10)

for i in range (0, 3):
    pag.click(checkbox_position)
    time.sleep(2)
    pag.click(ocultar_checkb_position)
    time.sleep(20)
    
pag.alert('Fim')
# Out:
# 'OK'

# %%
#pega posição do mouse
#pag.alert('Aperte ok, posicione o mouse no lugar a se obter a posição e aguarde 5 segundos')
time.sleep(7)
x, y = pag.position()
print('posição x: {}, posição y: {}'.format(x, y))
pag.alert('posição gravada')
# Out:
# posição x: 745, posição y: 661
# 'OK'
