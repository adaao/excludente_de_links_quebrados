# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

#abrir navegador
navegador = webdriver.Chrome()

# %%
navegador.get('https://pt.semrush.com/')

# %%
navegador.get('https://pt.semrush.com/siteaudit/campaign/5243542/review#issue/detail/8/sorting/info_asc/page/1/filter/%2B%7Ctarget_url%7CCo%7Chttp%3A%2F%2Fzuportal.zu.ac.ae')
